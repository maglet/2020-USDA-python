# %% [markdown]
# # Markdown
# * plain-text format
# * renders into HTML like format
#
# ## To create a Markdown cell
# 1. Select Mardown from the dropdown second from the right
# 1. Write your content in Mardown
# 1. Hit Shift-Enter to render the code

# %%
2+2
# Out:
# 4

# %%
2+2
5+5
# Out:
# 10

# %%
print(2+2)
5+5
# Out:
# 4
# 10

# %% [markdown]
# # Built-in Functions
# and how to get help with using them

# %% [markdown]
# ## Functions...
# * have names
# * take input (`arguments`) - number varies by function
# * present output

# %%
# example: print is a function
# * name  = print
# * input = before
# * output = prints 'before' to the screen

print('before')
# Out:
# before

# %% [markdown]
# ### Other functions

# %%
# example: 
# * name  = max
# * input = numbers
# * output = the biggest number
max(1,2,3) # finds the largest number
# Out:
# 3

# %%
# example: 
# * name  = min
# * input = characters
# * output = the 'smallest' character based on ASCII value
min('a', 'A', '0') # finds the largest number
# Out:
# '0'

# %%
# but don't mix numbers and letters

min(1,'a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-98cdc063cc20> in <module>
#       1 # but don't mix numbers and letters
#       2
# ----> 3 min(1,'a')
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# ### Default arguments
#
# some functions have default values for some inputs
#
# Example: `round`

# %%
round(3.14159) #defaults to 0 decimal places
# Out:
# 3

# %%
round(3.14159, 2) #change the default
# Out:
# 3.14

# %% [markdown]
# # Exercise
#
# **Predict what each of the print statements in the program below will print.**
#
# ```
# easy_string = "abc"
# print(max(easy_string))
# rich = "gold"
# poor = "tin"
# print(max(rich, poor))
# print(max(len(rich), len(poor)))
# ```

# %% [markdown]
# ## Answer

# %%
easy_string = "abc"
print(max(easy_string))
rich = "gold"
poor = "tin" 
print(max(rich, poor))
print(max(len(rich), len(poor)))
# Out:
# c
# tin
# 4

# %% [markdown]
# ## Getting help
#
# How to find out
# * what a function does
# * what input does it take? are there default values?
# * what is the ouput?
#
# Use the `help` function
# * takes a function name as input
# * outputs a help file to the screen

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %% [markdown]
# ## Syntax errors
#
# Python reports a syntax error if it can't understand the code. It won't try to run it

# %%
# example: missing ending quote

name = 'Feng
# Out:
#   File "<ipython-input-9-576bc20b1676>", line 3
#     name = 'Feng
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
# example: too many = 

age = = 52
# Out:
#   File "<ipython-input-10-ff9a15d2197f>", line 3
#     age = = 52
#           ^
# SyntaxError: invalid syntax

# %%
# example: no closing )
print("Hello World"
# Out:
#   File "<ipython-input-11-7f5aa1dd7370>", line 2
#     print("Hello World"
#                        ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ## Runtime errors
#
# When something goes wrong while the code is running

# %%
age = 53
remaining = 100-aege #age is mispelled
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-13d6564eb955> in <module>
#       1 age = 53
# ----> 2 remaining = 100-aege #age is mispelled
#
# NameError: name 'aege' is not defined

# %% [markdown]
# # Exercise
#
#
# **Given the following code, why does max(len(rich), poor)  produce an error message?**
#
# ```
# rich = "gold"
# poor = "tin"
# max(len(rich), poor)
# ```

# %% [markdown]
# ## answer

# %%
rich = "gold"
poor = "tin" 
max(len(rich), poor)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-094c14b339f8> in <module>
#       1 rich = "gold"
#       2 poor = "tin"
# ----> 3 max(len(rich), poor)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# len(rich
